# %% [markdown]
# # Cohort Analysis

# %% [markdown]
# ## Load Library & Dataset

# %%
#import librarys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
from scipy.stats import skew, kurtosis

# %%
#import Dataset
retail = pd.read_excel('Online Retail.xlsx')

retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ## Pre-Processing Data

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# ## Duplicated Value

# %%
retail.duplicated().sum()
# Out:
# 5268

# %%
# Menampilkan baris yang terduplikasi
duplicate_rows = retail[retail.duplicated()]  # `
duplicate_rows.head()
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 517    536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527    536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537    536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539    536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555    536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 517 2010-12-01 11:45:00       1.25     17908.0  United Kingdom
# 527 2010-12-01 11:45:00       2.10     17908.0  United Kingdom
# 537 2010-12-01 11:45:00       2.95     17908.0  United Kingdom
# 539 2010-12-01 11:45:00       4.95     17908.0  United Kingdom
# 555 2010-12-01 11:49:00       2.95     17920.0  United Kingdom

# %%
total_data = len(retail)
total_duplicates = retail.duplicated().sum()
percentage_duplicates = (total_duplicates / total_data) * 100
percentage_duplicates
# Out:
# 0.9721189350979592

# %%
retail = retail.drop_duplicates()
retail.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Missing Value

# %%
retail.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
missing_percentage = retail.isna().mean() * 100
missing_percentage
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.270945
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     25.163377
# Country         0.000000
# dtype: float64

# %% [markdown]
# Terdapat nilai hilang pada kolom Description sebesar 0.27% dari total data, dan 25% pada kolom CustomerID. Opsi handling missing value :
#
#
# 1. Menghapus baris adalah solusi yang paling sederhana namun bisa mengurangi jumlah data yang signifikan. Penghapusan ini cocok jika jumlah data yang cukup besar sehingga kehilangan sebagian data tidak terlalu mempengaruhi analisis keseluruhan.
#
# 2. Jika CustomerID adalah numerik (meskipun biasanya merupakan identifier dan bukan variabel kuantitatif), kamu bisa mengisinya dengan nilai statistik seperti mean atau median. Namun, pada kasus CustomerID, pengisian nilai mungkin tidak relevan karena bersifat kategorikal dan unik untuk setiap konsumen.
#
# 3. Untuk data kategorikal seperti CustomerID, pengisian dengan modus bisa menjadi pilihan, asalkan ada asumsi yang logis di balik penggunaan ID pelanggan yang sama untuk transaksi yang berbeda.
#
# 4. Untuk CustomerID, kamu bisa menetapkan suatu nilai khusus untuk mewakili data yang hilang, seperti menggantinya dengan "Unknown" atau nilai spesifik lain. Ini memungkinkan kamu untuk tetap menyertakan baris data dalam analisis tanpa harus menghapusnya.

# %%
# Isi nilai yang hilang dengan 'Unknown' atau ID unik lainnya
retail['CustomerID'].fillna('Unknown', inplace=True)
retail['Description'].fillna('Unknown', inplace=True)

retail.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
retail.describe()
# Out:
#             Quantity      UnitPrice
# count  536641.000000  536641.000000
# mean        9.620029       4.632656
# std       219.130156      97.233118
# min    -80995.000000  -11062.060000
# 25%         1.000000       1.250000
# 50%         3.000000       2.080000
# 75%        10.000000       4.130000
# max     80995.000000   38970.000000

# %%
retail[retail['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 141    2010-12-01 09:41:00      27.50    14527.0  United Kingdom
# 154    2010-12-01 09:49:00       4.65    15311.0  United Kingdom
# 235    2010-12-01 10:24:00       1.65    17548.0  United Kingdom
# 236    2010-12-01 10:24:00       0.29    17548.0  United Kingdom
# 237    2010-12-01 10:24:00       0.29    17548.0  United Kingdom
# ...                    ...        ...        ...             ...
# 540449 2011-12-09 09:57:00       0.83    14397.0  United Kingdom
# 541541 2011-12-09 10:28:00     224.69    15498.0  United Kingdom
# 541715 2011-12-09 11:57:00      10.95    15311.0  United Kingdom
# 541716 2011-12-09 11:58:00       1.25    17315.0  United Kingdom
# 541717 2011-12-09 11:58:00       1.25    17315.0  United Kingdom
#
# [10587 rows x 8 columns]

# %%
# Filter data di mana Quantity < 0
filtered_df = retail[retail['Quantity'] < 0]

# Hitung jumlah baris yang memenuhi kriteria
jumlah = filtered_df.shape[0]
total = retail.shape[0]
persentase = (jumlah / total) * 100

print("Quantity < 0:", jumlah)
print("% Quantity < 0 :", persentase, "%")
# Out:
# Quantity < 0: 10587
# % Quantity < 0 : 1.9728272718633126 %

# %%
# Filter data di mana UnitPrice < 0
filtered_df = retail[retail['UnitPrice'] < 0]

# Hitung jumlah baris yang memenuhi kriteria
jumlah = filtered_df.shape[0]
total = retail.shape[0]
persentase = (jumlah / total) * 100

print("UnitPrice < 0:", jumlah)
print("% UnitPrice < 0 :", persentase, "%")
# Out:
# UnitPrice < 0: 2
# % UnitPrice < 0 : 0.00037268863169232316 %

# %% [markdown]
# Terdapat nilai minus pada Quantity dan UnitPrice, dalam bisnis retail hal ini mungkin dapat terjadi untuk tipe barang yang melakukan proses return. namun pada case kali ini kami memutuskan untuk menghilangkan data dengan Quantity dan UnitPrice < 0.

# %%
# Filter data untuk memilih baris di mana Quantity > 0 dan UnitPrice > 0
retail_df = retail[(retail['Quantity'] > 0) & (retail['UnitPrice'] > 0)]

# Menampilkan deskripsi statistik dari DataFrame yang telah difilter
retail_df.describe()
# Out:
#             Quantity      UnitPrice
# count  524878.000000  524878.000000
# mean       10.616600       3.922573
# std       156.280031      36.093028
# min         1.000000       0.001000
# 25%         1.000000       1.250000
# 50%         4.000000       2.080000
# 75%        11.000000       4.130000
# max     80995.000000   13541.330000

# %% [markdown]
# ## Univariate Analysis

# %%
# Numerical datatypes
retail_df.select_dtypes(include=['int64','float64','Int64']).dtypes
# Out:
# Quantity       int64
# UnitPrice    float64
# dtype: object

# %%
retail_df.shape
# Out:
# (524878, 8)

# %%
columns = ['Quantity', 'UnitPrice']

fig, axs = plt.subplots(1, len(columns), figsize=(10, 4))

for i, col in enumerate(columns):
    # Histogram
    axs[i].hist(retail_df[col], edgecolor='black')  # Menggunakan axs[i] bukan axs[0, i]
    axs[i].set_title(f'Distribution of {col}')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
columns = ['Quantity', 'UnitPrice']

fig, axs = plt.subplots(1, len(columns), figsize=(10, 4))

for i, col in enumerate(columns):
    # Boxplot
    axs[i].boxplot(retail_df[col], patch_artist=True)  # Menggunakan patch_artist untuk menerapkan warna pada box
    axs[i].set_title(f'Distribution of {col}')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Kolom yang akan diplot
columns_to_plot = ['Quantity', 'UnitPrice']

# Membuat subplot dengan 1 baris dan 2 kolom
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Melakukan iterasi untuk membuat scatter plot untuk setiap kolom
for i, col in enumerate(columns_to_plot):
    axes[i].scatter(range(len(retail_df[col])), retail_df[col], marker='o', label=col)
    
    # Menambahkan label dan judul
    axes[i].set_xlabel('Index')
    axes[i].set_ylabel('Nilai')
    axes[i].set_title(f'Scatter Plot untuk {col}')
    axes[i].legend()

# Menampilkan subplot
plt.show()

# %%
columns = ['Quantity', 'UnitPrice']
outlier_info = {}

for column in columns:
    column_data = retail_df[column]

    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = column_data[(column_data < lower_bound) | (column_data > upper_bound)]
    outlier_percentage = len(outliers) / len(column_data) * 100
    
    outlier_info[column] = {
        'lower_bound': lower_bound,
        'upper_bound': upper_bound,
        'outliers': outliers,
        'outlier_percentage': outlier_percentage
    }

# Menampilkan informasi outlier untuk setiap kolom
for column, info in outlier_info.items():
    print(f"Column '{column}':")
    print(f"  Lower Bound: {info['lower_bound']}")
    print(f"  Upper Bound: {info['upper_bound']}")
    print(f"  Outliers: {len(info['outliers'])}")
    print(f"  Persentase outlier: {info['outlier_percentage']:.2f}%\n")
# Out:
# Column 'Quantity':
#   Lower Bound: -14.0
#   Upper Bound: 26.0
#   Outliers: 27111
#   Persentase outlier: 5.17%
#
# Column 'UnitPrice':
#   Lower Bound: -3.0700000000000003
#   Upper Bound: 8.45
#   Outliers: 37827
#   Persentase outlier: 7.21%

# %%
# define lower and upper bounds
lower_bounds, upper_bounds = [], []

for column in columns :
    lower_bound = retail_df[column].describe()['25%'] - (1.5 * (retail_df[column].describe()['75%'] - retail_df[column].describe()['25%']))
    upper_bound = retail_df[column].describe()['75%'] + (1.5 * (retail_df[column].describe()['75%'] - retail_df[column].describe()['25%']))
    lower_bounds.append(lower_bound)
    upper_bounds.append(upper_bound)
    
print(lower_bounds)
print(upper_bounds)
# Out:
# [-14.0, -3.0700000000000003]
# [26.0, 8.45]

# %%
# create new df without outliers
retail_cleans = retail_df.copy()
for n, column in enumerate(columns):
    retail_cleans = retail_cleans[(retail_cleans[column] >= lower_bounds[n]) & (retail_cleans[column] <= upper_bounds[n])]
    
print(f'Observations removed = {1 - retail_cleans.shape[0]/retail_df.shape[0]:.2%}')
# Out:
# Observations removed = 12.31%

# %%
#outliers = column_data[(column_data < lower_bound) | (column_data > upper_bound)]
len(retail_cleans[(retail_cleans[column] < lower_bounds[n]) | (retail_cleans[column] > upper_bounds[n])])
# Out:
# 0

# %%
columns = ['Quantity', 'UnitPrice']

fig, axs = plt.subplots(1, len(columns), figsize=(10, 4))

for i, col in enumerate(columns):
    # Histogram
    axs[i].hist(retail_cleans[col], edgecolor='black')  # Menggunakan axs[i] bukan axs[0, i]
    axs[i].set_title(f'Distribution of {col}')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
columns = ['Quantity', 'UnitPrice']

fig, axs = plt.subplots(1, len(columns), figsize=(10, 4))

for i, col in enumerate(columns):
    # Boxplot
    axs[i].boxplot(retail_cleans[col], patch_artist=True)  # Menggunakan patch_artist untuk menerapkan warna pada box
    axs[i].set_title(f'Distribution of {col}')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Kolom yang akan diplot
columns_to_plot = ['Quantity', 'UnitPrice']

# Membuat subplot dengan 1 baris dan 2 kolom
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Melakukan iterasi untuk membuat scatter plot untuk setiap kolom
for i, col in enumerate(columns_to_plot):
    axes[i].scatter(range(len(retail_cleans[col])), retail_cleans[col], marker='o', label=col)
    
    # Menambahkan label dan judul
    axes[i].set_xlabel('Index')
    axes[i].set_ylabel('Nilai')
    axes[i].set_title(f'Scatter Plot untuk {col}')
    axes[i].legend()

# Menampilkan subplot
plt.show()
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Visualisasi Histogram
plt.figure(figsize=(12, 6))

# Histogram
plt.subplot(1, 3, 1)
sns.histplot(retail_cleans['Quantity'], bins=30, kde=True, color='blue')
plt.title('Histogram')

# Skewness
plt.subplot(1, 3, 2)
sns.kdeplot(retail_cleans['Quantity'], color='red')
plt.axvline(retail_cleans['Quantity'].mean(), color='green', linestyle='--', label='Mean')
plt.axvline(retail_cleans['Quantity'].median(), color='purple', linestyle='--', label='Median')
plt.title(f'Skewness: {skew(retail_cleans["Quantity"]):.2f}')
plt.legend()

# Kurtosis
plt.subplot(1, 3, 3)
sns.boxplot(retail_cleans['Quantity'], color='orange')
plt.title(f'Kurtosis: {kurtosis(retail_cleans["Quantity"]):.2f}')

plt.show()

# %%
# Visualisasi Histogram
plt.figure(figsize=(12, 6))

# Histogram
plt.subplot(1, 3, 1)
sns.histplot(retail_cleans['UnitPrice'], bins=30, kde=True, color='blue')
plt.title('Histogram')

# Skewness
plt.subplot(1, 3, 2)
sns.kdeplot(retail_cleans['UnitPrice'], color='red')
plt.axvline(retail_cleans['UnitPrice'].mean(), color='green', linestyle='--', label='Mean')
plt.axvline(retail_cleans['UnitPrice'].median(), color='purple', linestyle='--', label='Median')
plt.title(f'Skewness: {skew(retail_cleans["UnitPrice"]):.2f}')
plt.legend()

# Kurtosis
plt.subplot(1, 3, 3)
sns.boxplot(retail_cleans['UnitPrice'], color='orange')
plt.title(f'Kurtosis: {kurtosis(retail_cleans["UnitPrice"]):.2f}')

plt.show()
